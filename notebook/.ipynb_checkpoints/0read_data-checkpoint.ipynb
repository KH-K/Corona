# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import folium
import networkx as nx

# %%
patient_info = pd.read_csv("/home/kh/19Fall/Corona/data/PatientInfo.csv")
region = pd.read_csv("/home/kh/19Fall/Corona/data/Region.csv")
travel_route = pd.read_csv("~/19Fall/Corona/data/travel_route.csv")

# %% [markdown]
# ### check data

# %%
patient_info.head(10)
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
# 5  1000000006        10.0  female      1966.0  50s   Korea    Seoul
# 6  1000000007        11.0    male      1995.0  20s   Korea    Seoul
# 7  1000000008        13.0    male      1992.0  20s   Korea    Seoul
# 8  1000000009        19.0    male      1983.0  30s   Korea    Seoul
# 9  1000000010        21.0  female      1960.0  60s   Korea    Seoul
#
#           city  disease        infection_case   infected_by confirmed_date
# 0   Gangseo-gu      NaN       overseas inflow           NaN     2020-01-23
# ...

# %%
travel_route.head(10)
# Out:
#    patient_id  global_num        date     province           city  \
# 0  1000000001         2.0  2020-01-22  Gyeonggi-do       Gimpo-si
# 1  1000000001         2.0  2020-01-24        Seoul        Jung-gu
# 2  1000000002         5.0  2020-01-25        Seoul    Seongbuk-gu
# 3  1000000002         5.0  2020-01-26        Seoul    Seongbuk-gu
# 4  1000000002         5.0  2020-01-26        Seoul   Seongdong-gu
# 5  1000000002         5.0  2020-01-26        Seoul    Seongbuk-gu
# 6  1000000002         5.0  2020-01-26        Seoul    Seongbuk-gu
# 7  1000000002         5.0  2020-01-27        Seoul    Seongbuk-gu
# 8  1000000002         5.0  2020-01-27        Seoul  Dongdaemun-gu
# 9  1000000002         5.0  2020-01-28        Seoul    Seongbuk-gu
#
#                     type   latitude   longitude
# 0                airport  37.615246  126.715632
# 1               hospital  37.567241  127.005659
# 2                    etc  37.592560  127.017048
# ...

# %%
region.head(10)
# Out:
#     code province          city   latitude   longitude  \
# 0  10000    Seoul         Seoul  37.566953  126.977977
# 1  10010    Seoul    Gangnam-gu  37.518421  127.047222
# 2  10020    Seoul   Gangdong-gu  37.530492  127.123837
# 3  10030    Seoul    Gangbuk-gu  37.639938  127.025508
# 4  10040    Seoul    Gangseo-gu  37.551166  126.849506
# 5  10050    Seoul     Gwanak-gu  37.478290  126.951502
# 6  10060    Seoul   Gwangjin-gu  37.538712  127.082366
# 7  10070    Seoul       Guro-gu  37.495632  126.887650
# 8  10080    Seoul  Geumcheon-gu  37.456852  126.895229
# 9  10090    Seoul      Nowon-gu  37.654259  127.056294
#
#    elementary_school_count  kindergarten_count  university_count  \
# 0                      607                 830                48
# 1                       33                  38                 0
# 2                       27                  32                 0
# 3                       14                  21                 0
# ...

# %% [markdown]
# ### infection case

# %%
for i in range(len(patient_info)):
    if patient_info['infection_case'][i] == 'oversea inflow':
        patient_info['infection_case'][i] = 'oversea inflow'
    else:
        pass
# Out:
# /home/kh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
infection_route_count = None
infection_route_count = patient_info[['infection_case']]\
.dropna(axis = 0).astype('str')\
.groupby('infection_case')['infection_case'].count().reset_index(name = 'count')\
.sort_values(['count'], ascending = False)

top_infection_route = infection_route_count.head(10)
sns.barplot(x = 'count', y = 'infection_case',
           data = top_infection_route, orient = 'h',
           order = top_infection_route['infection_case'])
plt.show()

# %% [markdown]
# ### Spreader

# %%
spreader_count = None
spreader_count = patient_info[['infected_by']]\
.dropna(axis = 0).astype('int64')\
.groupby('infected_by')['infected_by'].count().reset_index(name = 'count')\
.sort_values(['count'], ascending = False)

top_spreader = spreader_count.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0924ffda3383> in <module>
#       1 spreader_count = None
# ----> 2 spreader_count = patient_info(['infected_by'])
#
# TypeError: 'DataFrame' object is not callable
